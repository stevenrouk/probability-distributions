# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %% [markdown]
# ## Function to graph samples from any distribution

# %%
def plot_distribution(samples, plot_kind='line'):
    if plot_kind == 'hist':
        _ = plt.hist(samples)
    else:
        samples_df = pd.DataFrame(samples, columns=["samples"])
        counts = samples_df["samples"].value_counts()
        counts = counts.sort_index()
        _ = counts.plot(kind=plot_kind)
        _ = plt.ylabel('value counts')

    return True

# %% [markdown]
# ## **Distributions in `np.random`:**
#
# beta, binomial, chisquare, dirichlet, exponential, f, gamma, geometric, gumbel, hypergeometric, laplace, logistic, lognormal, logseries, mtrand, multinomial, multivariate_normal, negative_binomial, noncentral_chisquare, noncentral_f, normal, pareto, poisson, power, rayleigh, standard_cauchy, standard_exponential, standard_gamma, standard_normal, standard_t, triangular, uniform, vonmises, wald, weibull, zipf

# %% [markdown]
# ### Beta distribution
# beta(a, b, size=None)
#
# The Beta distribution is a special case of the Dirichlet distribution,
# and is related to the Gamma distribution.
#
# It is often seen in Bayesian inference and order statistics.

# %%
_ = plot_distribution(np.random.beta(1, 1, size=100000), plot_kind='hist')

# %%
_ = plot_distribution(np.random.beta(0.3, 0.7, size=100000), plot_kind='hist')

# %%
_ = plot_distribution(np.random.beta(0.5, 0.5, size=100000), plot_kind='hist')

# %%
_ = plot_distribution(np.random.beta(0.1, 0.9, size=100000), plot_kind='hist')

# %%
_ = plot_distribution(np.random.beta(0.9, 0.1, size=100000), plot_kind='hist')

# %%
_ = plot_distribution(np.random.beta(0.9, 0.9, size=100000), plot_kind='hist')

# %% [markdown]
# ### Chi Squared distribution
# chisquare(df, size=None)
#
# When `df` independent random variables, each with standard normal
# distributions (mean 0, variance 1), are squared and summed, the
# resulting distribution is chi-square (see Notes).
#
# This distribution is often used in hypothesis testing.

# %%
np.random.chisquare(0.5, size=10)
# Out:
# array([1.09105403e-08, 1.53124576e-04, 2.27601093e-02, 4.35874057e-03,
#        1.52618908e+00, 7.54923672e-02, 1.38951916e-01, 1.66699761e+00,
#        7.54622120e-05, 6.30062286e-05])

# %%
_ = plot_distribution(np.random.chisquare(0.5, size=100000), plot_kind='hist')

# %%
_ = plot_distribution(np.random.chisquare(1, size=100000), plot_kind='hist')

# %%
_ = plot_distribution(np.random.chisquare(10, size=100000), plot_kind='hist')
